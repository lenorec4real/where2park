# %% [markdown]
# Data visualization
# meter_head
# Meter head type.
#
# r_mf_9a_6p
# Rate for Mon-Fri 9AM to 6PM.
#
# r_mf_6p_10
# Rate for Mon-Fri 6PM to 10PM.
#
# r_sa_9a_6p
# Rate for Sat 9AM to 6PM.
#
# r_sa_6p_10
# Rate for Sat 6PM to 10PM.
#
# r_su_9a_6p
# Rate for Sun 9AM to 6PM.
#
# r_su_6p_10
# Rate for Sun 6PM to 10PM.
#
# rate_misc
# Miscellaneous rate information.
#
# time_in_effect
# Times that meter is in effect.
#
# t_mf_9a_6p
# Time limit for Mon-Fri 9AM to 6PM.
#
# t_mf_6p_10
# Time limit for Mon-Fri 6PM to 10PM.
#
# t_sa_9a_6p
# Time limit for Sat 9AM to 6PM.
#
# t_sa_6p_10
# Time limit for Sat 6PM to 10PM.
#
# t_su_9a_6p
# Time limit for Sun 9AM to 6PM.
#
# t_su_6p_10
# Time limit for Sun 6PM to 10PM.
#
# time_misc
# Miscellaneous time limit information.
#
# credit_card
# Does the meter have credit card functionality?
#
# pay_phone
# Pay by Phone number.
#
# longitude
# Longitude coordinate.
#
# latitude
# Latitude coordinate.
#
# geo_local_area
# The local area where the meter is found, derived from meter's coordinates.
#
# meter_id
# Unique identifier generated by the system.

# %%
import pandas as pd

# %%
df = pd.read_csv('parking-meters.csv',sep=';')

# %%
df.describe()
# Out:
#        METERHEAD R_MF_9A_6P R_MF_6P_10 R_SA_9A_6P R_SA_6P_10 R_SU_9A_6P  \
# count       9005       9001       9001       9001       9001       9001
# unique         7         14         12         14         12         15
# top         Twin      $1.00      $1.00      $1.00      $1.00      $1.00
# freq        7237       3573       5564       3573       5536       3572
#
#        R_SU_6P_10 RATE_MISC                            TIMEINEFFE T_MF_9A_6P  \
# count        9001       771                                  8978       9000
# unique         13         9                                     1          8
# top         $1.00     $ .50  METER IN EFFECT: 9:00 AM TO 10:00 PM       2 Hr
# freq         5522       360                                  8978       6921
#
#         ... T_SA_9A_6P T_SA_6P_10 T_SU_9A_6P T_SU_6P_10      TIME_MISC  \
# count   ...       9000       9000       9000       9000            493
# unique  ...          7          8          7          8              4
# top     ...       2 Hr       4 Hr       2 Hr       4 Hr  No Time Limit
# freq    ...       6822       8752       6822       8739            362
#
#        CREDITCARD PAY_PHONE  \
# count        9003      9005
# unique          2      8865
# top            No     59831
# freq         8057         8
#
#                                                      Geom Geo Local Area  \
# count                                                9005           9005
# unique                                               5186             18
# top     {"type": "Point", "coordinates": [-123.1096255...       Downtown
# freq                                                    2           3135
#
#        METERID
# count     9005
# unique    9005
# top     121602
# freq         1
#
# [4 rows x 21 columns]

# %%
df.head()
# Out:
#   METERHEAD R_MF_9A_6P R_MF_6P_10 R_SA_9A_6P R_SA_6P_10 R_SU_9A_6P R_SU_6P_10  \
# 0      Twin      $1.00      $1.00      $1.00      $1.00      $1.00      $1.00
# 1      Twin      $1.00      $1.00      $1.00      $1.00      $1.00      $1.00
# 2      Twin      $4.00      $1.00      $4.00      $1.00      $4.00      $1.00
# 3      Twin      $1.00      $1.00      $1.00      $1.00      $1.00      $1.00
# 4      Twin      $3.00      $2.00      $3.00      $2.00      $3.00      $2.00
#
#   RATE_MISC                            TIMEINEFFE T_MF_9A_6P  ... T_SA_9A_6P  \
# 0       NaN  METER IN EFFECT: 9:00 AM TO 10:00 PM       3 Hr  ...       3 Hr
# 1       NaN  METER IN EFFECT: 9:00 AM TO 10:00 PM       3 Hr  ...       3 Hr
# 2       NaN  METER IN EFFECT: 9:00 AM TO 10:00 PM       2 Hr  ...       2 Hr
# 3       NaN  METER IN EFFECT: 9:00 AM TO 10:00 PM       3 Hr  ...       3 Hr
# 4       NaN  METER IN EFFECT: 9:00 AM TO 10:00 PM       3 Hr  ...       3 Hr
#
#   T_SA_6P_10 T_SU_9A_6P T_SU_6P_10 TIME_MISC CREDITCARD PAY_PHONE  \
# 0       4 Hr       3 Hr       4 Hr       NaN         No     56290
# 1       4 Hr       3 Hr       4 Hr       NaN         No     65151
# 2       4 Hr       2 Hr       4 Hr       NaN         No     52797
# 3       4 Hr       3 Hr       4 Hr       NaN         No     65485
# 4       4 Hr       3 Hr       4 Hr       NaN         No     60976
#
#                                                 Geom       Geo Local Area  \
# 0  {"type": "Point", "coordinates": [-123.0374626...  Renfrew-Collingwood
# 1  {"type": "Point", "coordinates": [-123.1102209...             Downtown
# 2  {"type": "Point", "coordinates": [-123.1393795...             Fairview
# 3  {"type": "Point", "coordinates": [-123.1223684...             Downtown
# 4  {"type": "Point", "coordinates": [-123.1237987...             Downtown
#
#   METERID
# 0  993205
# 1  270604
# 2  B71506
# 3  601010
# 4  581216
#
# [5 rows x 21 columns]
